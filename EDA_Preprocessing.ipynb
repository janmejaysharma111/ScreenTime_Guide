# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('screen_time_dataset.csv')
data.describe()
# Out:
#             log_id  time_watched_min  session_count  avg_session_length_min  \
# count  3842.000000       3842.000000    3842.000000             3842.000000
# mean   1921.500000         43.248282       2.187142               23.811973
# std    1109.234195         45.644648       1.471277               26.637056
# min       1.000000          3.000000       1.000000                0.700000
# 25%     961.250000         13.600000       1.000000                7.900000
# 50%    1921.500000         27.800000       2.000000               15.400000
# 75%    2881.750000         54.975000       3.000000               29.375000
# max    3842.000000        335.300000      10.000000              258.000000
#
#        app_switches_during_session  addiction_score  \
# count                  3842.000000      3842.000000
# mean                      2.226445        48.344196
# std                       2.088076        36.136613
# min                       0.000000         0.000000
# ...

# %%
sns.scatterplot(data=data,x='time_watched_min',y='addiction_score', hue='category')
# Out:
# <Axes: xlabel='time_watched_min', ylabel='addiction_score'>

# %%
sns.boxplot(data=data, x='time_watched_min', y='category')
# Out:
# <Axes: xlabel='time_watched_min', ylabel='category'>
